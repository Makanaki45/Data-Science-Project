# %%
import pandas as pd

# %%
from matplotlib import pyplot as pt

# %%
result = pd.read_csv('results.csv')

# %%
result
# Out:
#              date home_team    away_team  home_score  away_score  \
# 0      1872-11-30  Scotland      England           0           0
# 1      1873-03-08   England     Scotland           4           2
# 2      1874-03-07  Scotland      England           2           1
# 3      1875-03-06   England     Scotland           2           2
# 4      1876-03-04  Scotland      England           3           0
# ...           ...       ...          ...         ...         ...
# 45310  2023-11-21     Wales       Turkey           1           1
# 45311  2023-11-21   Croatia      Armenia           1           0
# 45312  2023-11-21   Andorra       Israel           0           2
# 45313  2023-11-21    Kosovo      Belarus           0           1
# 45314  2023-11-21   Romania  Switzerland           1           0
#
#                     tournament              city   country  neutral
# 0                     Friendly           Glasgow  Scotland    False
# ...

# %%
shoot = pd.read_csv('shootouts.csv')

# %%
shoot
# Out:
#            date      home_team         away_team       winner first_shooter
# 0    1967-08-22          India            Taiwan       Taiwan           NaN
# 1    1971-11-14    South Korea  Vietnam Republic  South Korea           NaN
# 2    1972-05-07    South Korea              Iraq         Iraq           NaN
# 3    1972-05-17       Thailand       South Korea  South Korea           NaN
# 4    1972-05-19       Thailand          Cambodia     Thailand           NaN
# ..          ...            ...               ...          ...           ...
# 557  2023-07-12  United States            Panama       Panama           NaN
# 558  2023-09-07           Iraq             India         Iraq           NaN
# 559  2023-09-10       Thailand              Iraq         Iraq           NaN
# 560  2023-10-13           Iraq             Qatar        Qatar           NaN
# 561  2023-11-21         Mexico          Honduras       Mexico           NaN
#
# [562 rows x 5 columns]

# %%
result = result.merge(shoot)

# %%
result
# Out:
#            date    home_team         away_team  home_score  away_score  \
# 0    1967-08-22        India            Taiwan           1           1
# 1    1971-11-14  South Korea  Vietnam Republic           1           1
# 2    1972-05-07  South Korea              Iraq           0           0
# 3    1972-05-17     Thailand       South Korea           1           1
# 4    1972-05-19     Thailand          Cambodia           2           2
# ..          ...          ...               ...         ...         ...
# 556  2023-07-13        Åland  Falkland Islands           1           1
# 557  2023-09-07         Iraq             India           2           2
# 558  2023-09-10     Thailand              Iraq           2           2
# 559  2023-10-13         Iraq             Qatar           0           0
# 560  2023-11-21       Mexico          Honduras           2           0
#
#                   tournament           city   country  neutral       winner  \
# ...

# %%
result.shape
# Out:
# (561, 11)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 561 entries, 0 to 560
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           561 non-null    object
#  1   home_team      561 non-null    object
#  2   away_team      561 non-null    object
#  3   home_score     561 non-null    int64
#  4   away_score     561 non-null    int64
#  5   tournament     561 non-null    object
#  6   city           561 non-null    object
#  7   country        561 non-null    object
#  8   neutral        561 non-null    bool
#  9   winner         561 non-null    object
#  10  first_shooter  86 non-null     object
# dtypes: bool(1), int64(2), object(8)
# memory usage: 48.8+ KB

# %%
result.describe()
# Out:
#        home_score  away_score
# count  561.000000  561.000000
# mean     0.923351    0.841355
# std      0.863655    0.848192
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      1.000000    1.000000
# 75%      1.000000    1.000000
# max      4.000000    4.000000

# %%
result.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral', 'winner', 'first_shooter'],
#       dtype='object')

# %%
result=result.rename(columns={'date':'Date', 'home_team':'Home_Team', 'away_team':'Away_Team', 'home_score':'Home_Score', 'away_score':'Away_Score', 'tournament':'Tournament', 'city':'City', 'country':'Country', 'neutral':'Neutral', 'winner':'Winner', 'first_shooter':'First_Shooter'})

# %%
result
# Out:
#            Date    Home_Team         Away_Team  Home_Score  Away_Score  \
# 0    1967-08-22        India            Taiwan           1           1
# 1    1971-11-14  South Korea  Vietnam Republic           1           1
# 2    1972-05-07  South Korea              Iraq           0           0
# 3    1972-05-17     Thailand       South Korea           1           1
# 4    1972-05-19     Thailand          Cambodia           2           2
# ..          ...          ...               ...         ...         ...
# 556  2023-07-13        Åland  Falkland Islands           1           1
# 557  2023-09-07         Iraq             India           2           2
# 558  2023-09-10     Thailand              Iraq           2           2
# 559  2023-10-13         Iraq             Qatar           0           0
# 560  2023-11-21       Mexico          Honduras           2           0
#
#                   Tournament           City   Country  Neutral       Winner  \
# ...

# %%
result.isnull().sum()
# Out:
# Date               0
# Home_Team          0
# Away_Team          0
# Home_Score         0
# Away_Score         0
# Tournament         0
# City               0
# Country            0
# Neutral            0
# Winner             0
# First_Shooter    475
# dtype: int64

# %%
result[result.First_Shooter.isnull()]
# Out:
#            Date    Home_Team         Away_Team  Home_Score  Away_Score  \
# 0    1967-08-22        India            Taiwan           1           1
# 1    1971-11-14  South Korea  Vietnam Republic           1           1
# 2    1972-05-07  South Korea              Iraq           0           0
# 3    1972-05-17     Thailand       South Korea           1           1
# 4    1972-05-19     Thailand          Cambodia           2           2
# ..          ...          ...               ...         ...         ...
# 556  2023-07-13        Åland  Falkland Islands           1           1
# 557  2023-09-07         Iraq             India           2           2
# 558  2023-09-10     Thailand              Iraq           2           2
# 559  2023-10-13         Iraq             Qatar           0           0
# 560  2023-11-21       Mexico          Honduras           2           0
#
#                   Tournament           City   Country  Neutral       Winner  \
# ...

# %%
result['First_Shooter'] = result['First_Shooter'].fillna('')

# %%
result
# Out:
#            Date    Home_Team         Away_Team  Home_Score  Away_Score  \
# 0    1967-08-22        India            Taiwan           1           1
# 1    1971-11-14  South Korea  Vietnam Republic           1           1
# 2    1972-05-07  South Korea              Iraq           0           0
# 3    1972-05-17     Thailand       South Korea           1           1
# 4    1972-05-19     Thailand          Cambodia           2           2
# ..          ...          ...               ...         ...         ...
# 556  2023-07-13        Åland  Falkland Islands           1           1
# 557  2023-09-07         Iraq             India           2           2
# 558  2023-09-10     Thailand              Iraq           2           2
# 559  2023-10-13         Iraq             Qatar           0           0
# 560  2023-11-21       Mexico          Honduras           2           0
#
#                   Tournament           City   Country  Neutral       Winner  \
# ...

# %%
result.sort_values('First_Shooter', ascending=True)
# Out:
#            Date Home_Team     Away_Team  Home_Score  Away_Score  \
# 0    1967-08-22     India        Taiwan           1           1
# 358  2007-07-22      Iran   South Korea           0           0
# 357  2007-07-21     Japan     Australia           1           1
# 355  2007-05-26  Eswatini     Mauritius           0           0
# 354  2007-05-26    Malawi  South Africa           0           0
# ..          ...       ...           ...         ...         ...
# 223  1999-07-13   Uruguay         Chile           1           1
# 371  2010-07-02   Uruguay         Ghana           1           1
# 222  1999-07-10  Paraguay       Uruguay           1           1
# 257  2001-07-29   Uruguay      Honduras           2           2
# 172  1995-07-23   Uruguay        Brazil           1           1
#
#              Tournament          City       Country  Neutral        Winner  \
# 0    Merdeka Tournament  Kuala Lumpur      Malaysia     True        Taiwan
# ...

# %%
result.sort_values('First_Shooter', ascending=False)
# Out:
#            Date             Home_Team     Away_Team  Home_Score  Away_Score  \
# 257  2001-07-29               Uruguay      Honduras           2           2
# 172  1995-07-23               Uruguay        Brazil           1           1
# 371  2010-07-02               Uruguay         Ghana           1           1
# 494  2019-06-29               Uruguay          Peru           0           0
# 222  1999-07-10              Paraguay       Uruguay           1           1
# ..          ...                   ...           ...         ...         ...
# 195  1996-12-27                 Benin  Burkina Faso           0           0
# 194  1996-12-21  United Arab Emirates  Saudi Arabia           0           0
# 193  1996-12-21                  Iran        Kuwait           1           1
# 192  1996-12-19                  Iran  Saudi Arabia           0           0
# 560  2023-11-21                Mexico      Honduras           2           0
#
# ...

# %%
result.reset_index()
# Out:
#      index        Date    Home_Team         Away_Team  Home_Score  Away_Score  \
# 0        0  1967-08-22        India            Taiwan           1           1
# 1        1  1971-11-14  South Korea  Vietnam Republic           1           1
# 2        2  1972-05-07  South Korea              Iraq           0           0
# 3        3  1972-05-17     Thailand       South Korea           1           1
# 4        4  1972-05-19     Thailand          Cambodia           2           2
# ..     ...         ...          ...               ...         ...         ...
# 556    556  2023-07-13        Åland  Falkland Islands           1           1
# 557    557  2023-09-07         Iraq             India           2           2
# 558    558  2023-09-10     Thailand              Iraq           2           2
# 559    559  2023-10-13         Iraq             Qatar           0           0
# 560    560  2023-11-21       Mexico          Honduras           2           0
#
# ...

# %%
result.loc[result['Home_Team'] =='Iraq']
# Out:
#            Date Home_Team    Away_Team  Home_Score  Away_Score  \
# 64   1984-03-28      Iraq        Qatar           1           1
# 105  1988-07-21      Iraq        Syria           1           1
# 114  1989-11-12      Iraq       Uganda           1           1
# 279  2002-09-05      Iraq         Iran           0           0
# 359  2007-07-25      Iraq  South Korea           0           0
# 536  2022-09-23      Iraq         Oman           1           1
# 557  2023-09-07      Iraq        India           2           2
# 559  2023-10-13      Iraq        Qatar           0           0
#
#                           Tournament          City   Country  Neutral Winner  \
# 64                          Gulf Cup        Muscat      Oman     True   Iraq
# 105                         Arab Cup         Amman    Jordan     True   Iraq
# 114                         Friendly   Kuwait City    Kuwait     True   Iraq
# 279                WAFF Championship      Damascus     Syria     True   Iraq
# ...

# %%
result.loc[(result['Home_Team'] =='Iraq') & (result['Away_Team'] =='Syria') & (result['Home_Score']>0)]
# Out:
#            Date Home_Team Away_Team  Home_Score  Away_Score Tournament   City  \
# 105  1988-07-21      Iraq     Syria           1           1   Arab Cup  Amman
#
#     Country  Neutral Winner First_Shooter
# 105  Jordan     True   Iraq

# %%
result['Total Score'] = result.Home_Score + result.Away_Score

# %%
result
# Out:
#            Date    Home_Team         Away_Team  Home_Score  Away_Score  \
# 0    1967-08-22        India            Taiwan           1           1
# 1    1971-11-14  South Korea  Vietnam Republic           1           1
# 2    1972-05-07  South Korea              Iraq           0           0
# 3    1972-05-17     Thailand       South Korea           1           1
# 4    1972-05-19     Thailand          Cambodia           2           2
# ..          ...          ...               ...         ...         ...
# 556  2023-07-13        Åland  Falkland Islands           1           1
# 557  2023-09-07         Iraq             India           2           2
# 558  2023-09-10     Thailand              Iraq           2           2
# 559  2023-10-13         Iraq             Qatar           0           0
# 560  2023-11-21       Mexico          Honduras           2           0
#
#                   Tournament           City   Country  Neutral       Winner  \
# ...

# %%
result['Home_Team'].value_counts()
# Out:
# South Africa    15
# Zambia          15
# Thailand        13
# Senegal         12
# Iran            11
#                 ..
# Zanzibar         1
# Provence         1
# Panama           1
# Isle of Man      1
# Åland            1
# Name: Home_Team, Length: 164, dtype: int64

# %%
result['Home_Team'].unique()
# Out:
# array(['India', 'South Korea', 'Thailand', 'Senegal', 'Guinea',
#        'Mauritius', 'Cambodia', 'Malaysia', 'Bangladesh', 'Myanmar',
#        'Algeria', 'Qatar', 'Hong Kong', 'Syria', 'Libya', 'Morocco',
#        'Kenya', 'Czechoslovakia', 'Tunisia', 'Argentina', 'Zambia',
#        'Iran', 'Paraguay', 'Guinea-Bissau', 'Cameroon', 'Gambia', 'Italy',
#        'Nigeria', 'Mali', 'Rwanda', 'Ivory Coast', 'Germany', 'Indonesia',
#        'Uganda', 'Egypt', 'Sierra Leone', 'Iraq', 'Denmark', 'Ghana',
#        'Saudi Arabia', 'Malawi', 'Chad', 'Central African Republic',
#        'Congo', 'Mozambique', 'Madagascar', 'Bahrain', 'Brazil', 'Mexico',
#        'Spain', 'Gabon', 'Australia', 'DR Congo', 'Equatorial Guinea',
#        'Ethiopia', 'Canada', 'Chile', 'Eswatini', 'China PR',
#        'United States', 'Colombia', 'Zimbabwe', 'Republic of Ireland',
#        'Yugoslavia', 'Tanzania', 'Fiji', 'Netherlands', 'Cuba', 'Japan',
# ...

# %%
ax = result['Home_Team'].value_counts().head().plot(kind='bar')
ax.set_xlabel('Home_Team')
ax.set_ylabel('Result')
ax.set_title('Graph Showing the Home_Team Result')
# Out:
# Text(0.5, 1.0, 'Graph Showing the Home_Team Result')

# %%
result['Away_Team'].value_counts()
# Out:
# Uganda                 15
# Egypt                  14
# South Korea            12
# Argentina              11
# Cameroon               10
#                        ..
# Slovenia                1
# Haiti                   1
# Trinidad and Tobago     1
# Ynys Môn                1
# India                   1
# Name: Away_Team, Length: 178, dtype: int64

# %%
result['Away_Team'].unique()
# Out:
# array(['Taiwan', 'Vietnam Republic', 'Iraq', 'South Korea', 'Cambodia',
#        'Ghana', 'Mali', 'Tanzania', 'Singapore', 'Kuwait', 'Thailand',
#        'Syria', 'United Arab Emirates', 'Indonesia', 'Morocco', 'Tunisia',
#        'Malaysia', 'Malawi', 'Germany', 'Iran', 'Algeria', 'Argentina',
#        'Guinea', 'Netherlands', 'Mauritania', 'Egypt', 'Czechoslovakia',
#        'China PR', 'Ethiopia', 'Togo', 'Burkina Faso', 'France', 'Kenya',
#        'Niger', 'Sierra Leone', 'Congo', 'Nigeria', 'Senegal', 'Cameroon',
#        'Qatar', 'Spain', 'Angola', 'Somalia', 'Zambia',
#        'Equatorial Guinea', 'Gabon', 'Libya', 'Uganda', 'Belgium',
#        'Australia', 'Zimbabwe', 'Sweden', 'Greece', 'Ecuador',
#        'Saudi Arabia', 'Sudan', 'Colombia', 'Russia', 'Eswatini',
#        'Romania', 'England', 'Ivory Coast', 'Honduras', 'Yugoslavia',
#        'Solomon Islands', 'Denmark', 'Martinique', 'Switzerland',
#        'Estonia', 'Paraguay', 'Saint Kitts and Nevis', 'Uruguay',
# ...

# %%
ax = result['Away_Team'].value_counts().head().plot(kind='bar')
ax.set_xlabel('Away_Team')
ax.set_ylabel('Result')
ax.set_title('Graph Showing the Away_Team Result')
# Out:
# Text(0.5, 1.0, 'Graph Showing the Away_Team Result')

# %%
result['Tournament'].value_counts()
# Out:
# Friendly                           85
# COSAFA Cup                         57
# African Cup of Nations             40
# FIFA World Cup                     35
# Copa América                       29
#                                    ..
# Merlion Cup                         1
# Great Wall Cup                      1
# Matthews Cup                        1
# CONMEBOL–UEFA Cup of Champions      1
# Jordan International Tournament     1
# Name: Tournament, Length: 68, dtype: int64

# %%
result['Tournament'].unique()
# Out:
# array(['Merdeka Tournament', "King's Cup", 'AFC Asian Cup',
#        'African Cup of Nations qualification', 'Palestine Cup',
#        'Gulf Cup', 'Kuneitra Cup', 'CECAFA Cup', 'UEFA Euro',
#        'FIFA World Cup qualification', 'Real Madrid 75th Anniversary Cup',
#        'Beijing International Friendship Tournament', 'Copa Félix Bogado',
#        'Amílcar Cabral Cup', 'FIFA 75th Anniversary Cup',
#        'African Cup of Nations', 'West African Cup', 'FIFA World Cup',
#        'Merlion Cup', 'Friendly', 'Great Wall Cup', 'UDEAC Cup',
#        'Arab Cup', 'Korea Cup', 'Matthews Cup', 'Dynasty Cup',
#        'Dakar Tournament', 'Gold Cup', 'South Pacific Games',
#        'CFU Caribbean Cup', 'CONMEBOL–UEFA Cup of Champions',
#        'Copa Paz del Chaco', 'Copa América', 'Confederations Cup',
#        'SAFF Cup', 'CFU Caribbean Cup qualification', 'UNCAF Cup',
#        'Lunar New Year Cup', 'King Hassan II Tournament', 'Nehru Cup',
# ...

# %%
pt.figure(figsize=(12,6))
ax = result['Tournament'].value_counts().plot(kind='bar')
ax.set_xlabel('Tournament')
ax.set_ylabel('Result')
ax.set_title('Graph Showing the Tournament Result')
# Out:
# Text(0.5, 1.0, 'Graph Showing the Tournament Result')
